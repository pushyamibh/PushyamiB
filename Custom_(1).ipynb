# %% [markdown]
# <a href="https://colab.research.google.com/github/PushyamiB/PushyamiB/blob/circleci-project-setup/Custom_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # !unzip /content/drive/MyDrive/CDD_latest.zip
# Out:
# Archive:  /content/drive/MyDrive/CDD_latest.zip
#    creating: CarDamage_tf2_gpu/
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/.gitignore
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/config.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/LICENSE
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/MANIFEST.in
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/model.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/model.py.bak
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/parallel_model.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/README.md
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/requirements.txt
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/setup.cfg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/setup.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/utils.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/visualize.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/visualize.py.bak
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/__init__.py
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/tests/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/tests/fixtures.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/tests/test_config.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/tests/test_model.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/tests/test_train.py
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/custom.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/custom1.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/demo.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/__init__.py
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/shapes/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/shapes/shapes.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/shapes/train_shapes.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/shapes/__init__.py
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/nucleus/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/nucleus/inspect_nucleus_data.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/nucleus/inspect_nucleus_model.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/nucleus/nucleus.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/nucleus/README.md
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/coco.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/coco.py.bak
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/inspect_data.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/inspect_model.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/coco/inspect_weights.ipynb
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/balloon/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/balloon/balloon.py
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/balloon/inspect_balloon_data.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/balloon/inspect_balloon_model.ipynb
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/samples/balloon/README.md
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/damage20190213T1434/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/damage20190213T1434/events.out.tfevents.1550048924.JASH-PC
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/damage20190213T1434/mask_rcnn_damage_0010.h5
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/1045023827_4ec3e8ba5c_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/12283150_12d37e6389_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/2383514521_1fc8d7b0de_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/2502287818_41e4b0c4fb_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/2516944023_d00345997d_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/25691390_f9944f61b5_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/262985539_1709e54576_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3132016470_c27baa00e8_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3627527276_6fe8cd9bfe_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3651581213_f81963d1dd_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3800883468_12af3c0b50_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3862500489_6fd195d183_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/3878153025_8fde829928_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/4410436637_7b0ca36ee7_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/4782628554_668bc31826_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/5951960966_d4e1cda5d0_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/6584515005_fce9cec486_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/6821351586_59aa0dc110_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/7581246086_cf7bbb7255_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/7933423348_c30bd9bd4e_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8053677163_d4c8f416be_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8239308689_efa6c11b08_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8433365521_9252889f9a_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8512296263_5fc5458e20_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8699757338_c3941051b6_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8734543718_37f6b8bd45_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/8829708882_48f263491e_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/9118579087_f9ffa19e63_z.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/images/9247489789_132c0d534a_z.jpg
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image61.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image62.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image63.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image64.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image65.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image72.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image73.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image74.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image75.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image75.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image76.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image77.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image78.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image79.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/image80.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/val/via_region_data.json
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image1.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image10.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image13.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image14.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image15.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image16.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image17.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image18.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image19.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image2.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image21.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image28.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image3.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image33.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image38.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image39.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image4.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image40.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image42.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image43.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image44.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image45.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image46.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image47.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image48.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image49.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image5.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image50.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image51.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image52.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image53.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image54.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image55.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image56.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image57.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image58.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image59.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image6.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image60.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image61.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image62.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image63.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image64.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image65.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image66.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image67.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image7.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image8.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/image9.jpeg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/train/via_region_data.json
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/test/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/test/test1.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/test/test2.jpg
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/4k_video.gif
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/balloon_color_splash.gif
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_activations.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_anchors.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_final.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_histograms.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_masks.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_refinement.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/detection_tensorboard.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/images_to_osm.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/mapping_challenge.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/nucleus_segmentation.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_3dbuildings.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_grass_gis.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_ice_wedge_polygons.png
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_shiny1.jpg
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_usiigaci1.gif
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/project_usiigaci2.gif
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/assets/street.png
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/.github/
#    creating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/.github/workflows/
#   inflating: CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/.github/workflows/pythonapp.yml

# %%
# !cd /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0 ; python setup.py install
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# creating mask_rcnn.egg-info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# error: package directory 'mrcnn' does not exist

# %%
# !cd /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0 ; python model.py install

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
import model as modellib
import utils
from config import Config
import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")
# Out:
# Downloading pretrained model to /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
class CustomConfig(Config):
    """Configuration for training on the custom dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "custom"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_CLASSES = 1 + 2  # Background + number of classes (Here, 2)

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 100

    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.9

# %%
class CustomDataset(utils.Dataset):

    def load_custom(self, dataset_dir, subset):
        """Load a subset of the custom dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes according to the numbe of classes required to detect
        self.add_class("custom", 1, "Scratch")
        self.add_class("custom",2,"Dent")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
            #labelling each class in the given image to a number

            custom = [s['region_attributes'] for s in a['regions'].values()]
            
            num_ids=[]
            #Add the classes according to the requirement
            for n in custom:
                try:
                    if n['label']=='Scratch':
                        num_ids.append(1)
                    elif n['label']=='Dent':
                        num_ids.append(2)
                except:
                    pass

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "custom",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a custom dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "custom":
            return super(self.__class__, self).load_mask(image_id)
        num_ids = image_info['num_ids']	
        #print("Here is the numID",num_ids)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
             #Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        num_ids = np.array(num_ids, dtype=np.int32)	
        return mask, np.ones([mask.shape[-1]], dtype=np.int32)#.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32), 

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "custom":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
import json
dataset_train = CustomDataset()
dataset_train.load_custom('/content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset', "train")
dataset_train.prepare()

    # Validation dataset
dataset_val = CustomDataset()
dataset_val.load_custom('/content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset', "val")
dataset_val.prepare()

# %%
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %%
# Create model object in inference mode.
config= CustomConfig()
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# Load weights trained on MS-COCO
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %%
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=10, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/custom20210818T0952/mask_rcnn_custom_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_7/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/GatherV2_2:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/GatherV2_5:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/GatherV2_8:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/GatherV2_11:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_7/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_2_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_2_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_2_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_3_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_3_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/ROI_7/GatherV2_3_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 100/100 [==============================] - ETA: 0s - batch: 49.5000 - size: 2.0000 - loss: 12.7657 - rpn_class_loss: 0.7030 - rpn_bbox_loss: 8.9250 - mrcnn_class_loss: 0.0426 - mrcnn_bbox_loss: 2.6587 - mrcnn_mask_loss: 0.4363
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 100/100 [==============================] - 262s 2s/step - batch: 49.5000 - size: 2.0000 - loss: 12.7657 - rpn_class_loss: 0.7030 - rpn_bbox_loss: 8.9250 - mrcnn_class_loss: 0.0426 - mrcnn_bbox_loss: 2.6587 - mrcnn_mask_loss: 0.4363 - val_loss: 8.3969 - val_rpn_class_loss: 0.2092 - val_rpn_bbox_loss: 5.8920 - val_mrcnn_class_loss: 0.0025 - val_mrcnn_bbox_loss: 1.9367 - val_mrcnn_mask_loss: 0.3565
# Epoch 2/10
# 100/100 [==============================] - 121s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 8.0921 - rpn_class_loss: 0.2018 - rpn_bbox_loss: 5.2878 - mrcnn_class_loss: 0.0350 - mrcnn_bbox_loss: 2.0168 - mrcnn_mask_loss: 0.5506 - val_loss: 4.7198 - val_rpn_class_loss: 0.1022 - val_rpn_bbox_loss: 2.6133 - val_mrcnn_class_loss: 0.0220 - val_mrcnn_bbox_loss: 1.3253 - val_mrcnn_mask_loss: 0.6570
# Epoch 3/10
# 100/100 [==============================] - 123s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 4.9298 - rpn_class_loss: 0.1406 - rpn_bbox_loss: 2.6851 - mrcnn_class_loss: 0.0594 - mrcnn_bbox_loss: 1.4252 - mrcnn_mask_loss: 0.6194 - val_loss: 2.3291 - val_rpn_class_loss: 0.0827 - val_rpn_bbox_loss: 1.0861 - val_mrcnn_class_loss: 0.0284 - val_mrcnn_bbox_loss: 0.6278 - val_mrcnn_mask_loss: 0.5040
# Epoch 4/10
# 100/100 [==============================] - 123s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.9082 - rpn_class_loss: 0.0995 - rpn_bbox_loss: 1.1033 - mrcnn_class_loss: 0.0644 - mrcnn_bbox_loss: 1.0409 - mrcnn_mask_loss: 0.6001 - val_loss: 2.8746 - val_rpn_class_loss: 0.0685 - val_rpn_bbox_loss: 1.1297 - val_mrcnn_class_loss: 0.0288 - val_mrcnn_bbox_loss: 1.0209 - val_mrcnn_mask_loss: 0.6265
# Epoch 5/10
# 100/100 [==============================] - 123s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.6389 - rpn_class_loss: 0.0906 - rpn_bbox_loss: 0.9769 - mrcnn_class_loss: 0.0528 - mrcnn_bbox_loss: 0.9013 - mrcnn_mask_loss: 0.6173 - val_loss: 2.2526 - val_rpn_class_loss: 0.0624 - val_rpn_bbox_loss: 0.8356 - val_mrcnn_class_loss: 0.0446 - val_mrcnn_bbox_loss: 0.7056 - val_mrcnn_mask_loss: 0.6042
# Epoch 6/10
# 100/100 [==============================] - 124s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.3079 - rpn_class_loss: 0.0925 - rpn_bbox_loss: 0.7509 - mrcnn_class_loss: 0.0612 - mrcnn_bbox_loss: 0.8001 - mrcnn_mask_loss: 0.6032 - val_loss: 2.4541 - val_rpn_class_loss: 0.0787 - val_rpn_bbox_loss: 0.8998 - val_mrcnn_class_loss: 0.0246 - val_mrcnn_bbox_loss: 0.9200 - val_mrcnn_mask_loss: 0.5309
# Epoch 7/10
# 100/100 [==============================] - 123s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.1928 - rpn_class_loss: 0.0875 - rpn_bbox_loss: 0.6786 - mrcnn_class_loss: 0.0674 - mrcnn_bbox_loss: 0.7650 - mrcnn_mask_loss: 0.5944 - val_loss: 2.2391 - val_rpn_class_loss: 0.0481 - val_rpn_bbox_loss: 0.7732 - val_mrcnn_class_loss: 0.0497 - val_mrcnn_bbox_loss: 0.7277 - val_mrcnn_mask_loss: 0.6404
# Epoch 8/10
# 100/100 [==============================] - 124s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.1671 - rpn_class_loss: 0.0791 - rpn_bbox_loss: 0.6752 - mrcnn_class_loss: 0.0629 - mrcnn_bbox_loss: 0.7475 - mrcnn_mask_loss: 0.6024 - val_loss: 2.5476 - val_rpn_class_loss: 0.0591 - val_rpn_bbox_loss: 0.7636 - val_mrcnn_class_loss: 0.0441 - val_mrcnn_bbox_loss: 0.9290 - val_mrcnn_mask_loss: 0.7518
# Epoch 9/10
# 100/100 [==============================] - 123s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 2.3234 - rpn_class_loss: 0.0871 - rpn_bbox_loss: 0.8248 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.7535 - mrcnn_mask_loss: 0.6047 - val_loss: 2.3656 - val_rpn_class_loss: 0.0818 - val_rpn_bbox_loss: 0.9259 - val_mrcnn_class_loss: 0.0219 - val_mrcnn_bbox_loss: 0.7615 - val_mrcnn_mask_loss: 0.5746
# Epoch 10/10
# 100/100 [==============================] - 125s 1s/step - batch: 49.5000 - size: 2.0000 - loss: 1.9955 - rpn_class_loss: 0.0788 - rpn_bbox_loss: 0.5836 - mrcnn_class_loss: 0.0583 - mrcnn_bbox_loss: 0.7165 - mrcnn_mask_loss: 0.5582 - val_loss: 1.7181 - val_rpn_class_loss: 0.1696 - val_rpn_bbox_loss: 0.6978 - val_mrcnn_class_loss: 0.0117 - val_mrcnn_bbox_loss: 0.3815 - val_mrcnn_mask_loss: 0.4575

# %%
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=5, 
            layers="all")
# Out:
# Starting at epoch 0. LR=0.0001
#
# Checkpoint Path: /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/logs/custom20210818T1043/mask_rcnn_custom_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# anchors                (AnchorsLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/5
#   1/100 [..............................] - ETA: 45:52 - batch: 0.0000e+00 - size: 2.0000 - loss: 15.3613 - rpn_class_loss: 10.4587 - rpn_bbox_loss: 3.6045 - mrcnn_class_loss: 1.2981 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-81-7c4c888ea8a3> in <module>()
#       2             learning_rate=config.LEARNING_RATE / 10,
#       3             epochs=5,
# ----> 4             layers="all")
#
# /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/model.py in train(self, train_dataset, val_dataset, learning_rate, epochs, layers, augmentation, custom_callbacks, no_augmentation_sources)
#    2370             max_queue_size=100,
#    2371             workers=workers,
# -> 2372             use_multiprocessing=False,
#    2373         )
#    2374         self.epoch = max(self.epoch, epochs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     794         max_queue_size=max_queue_size,
#     795         workers=workers,
# --> 796         use_multiprocessing=use_multiprocessing)
#     797
#     798   def evaluate(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_generator_v1.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing)
#     584         shuffle=shuffle,
#     585         initial_epoch=initial_epoch,
# --> 586         steps_name='steps_per_epoch')
#     587
#     588   def evaluate(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_generator_v1.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     250
#     251       is_deferred = not model._is_compiled
# --> 252       batch_outs = batch_function(*batch_data)
#     253       if not isinstance(batch_outs, list):
#     254         batch_outs = [batch_outs]
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1074       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1075       self._make_train_function()
# -> 1076       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1077
#    1078     if reset_metrics:
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in __call__(self, inputs)
#    4030
#    4031     fetched = self._callable_fn(*array_vals,
# -> 4032                                 run_metadata=self.run_metadata)
#    4033     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    4034     output_structure = tf.nest.pack_sequence_as(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1478         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1479                                                self._handle, args,
# -> 1480                                                run_metadata_ptr)
#    1481         if run_metadata:
#    1482           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[400,256,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training_2/SGD/gradients/gradients/mrcnn_mask_10/conv2d_76/Conv2D_grad/Conv2DBackpropInput}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.

# %%
model_path = 'model_finetune.h5'
model.keras_model.save_weights(model_path)

# %%
model.keras_model.summary()
# Out:
# Model: "mask_rcnn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, None, None,  0
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, None, None, 3 0           input_image[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNorm)            (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_666 (Activation)     (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 6 0           activation_666[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNorm)       (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_667 (Activation)     (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_667[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNorm)       (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_668 (Activation)     (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_668[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNorm)       (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNorm)        (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_297 (Add)                   (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_out (Activation)          (None, None, None, 2 0           add_297[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       res2a_out[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNorm)       (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_669 (Activation)     (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_669[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNorm)       (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_670 (Activation)     (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_670[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNorm)       (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_298 (Add)                   (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_out[0][0]
# __________________________________________________________________________________________________
# res2b_out (Activation)          (None, None, None, 2 0           add_298[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       res2b_out[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNorm)       (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_671 (Activation)     (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_671[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNorm)       (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_672 (Activation)     (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_672[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNorm)       (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_299 (Add)                   (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_out[0][0]
# __________________________________________________________________________________________________
# res2c_out (Activation)          (None, None, None, 2 0           add_299[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNorm)       (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_673 (Activation)     (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_673[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNorm)       (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_674 (Activation)     (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_674[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNorm)       (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNorm)        (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_300 (Add)                   (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_out (Activation)          (None, None, None, 5 0           add_300[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       res3a_out[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNorm)       (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_675 (Activation)     (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_675[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNorm)       (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_676 (Activation)     (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_676[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNorm)       (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_301 (Add)                   (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_out[0][0]
# __________________________________________________________________________________________________
# res3b_out (Activation)          (None, None, None, 5 0           add_301[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       res3b_out[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNorm)       (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_677 (Activation)     (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_677[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNorm)       (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_678 (Activation)     (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_678[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNorm)       (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_302 (Add)                   (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_out[0][0]
# __________________________________________________________________________________________________
# res3c_out (Activation)          (None, None, None, 5 0           add_302[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       res3c_out[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNorm)       (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_679 (Activation)     (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_679[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNorm)       (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_680 (Activation)     (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_680[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNorm)       (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_303 (Add)                   (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_out[0][0]
# __________________________________________________________________________________________________
# res3d_out (Activation)          (None, None, None, 5 0           add_303[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNorm)       (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_681 (Activation)     (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_681[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNorm)       (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_682 (Activation)     (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_682[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNorm)       (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNorm)        (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_304 (Add)                   (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_out (Activation)          (None, None, None, 1 0           add_304[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      res4a_out[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNorm)       (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_683 (Activation)     (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_683[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNorm)       (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_684 (Activation)     (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_684[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNorm)       (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_305 (Add)                   (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_out[0][0]
# __________________________________________________________________________________________________
# res4b_out (Activation)          (None, None, None, 1 0           add_305[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      res4b_out[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNorm)       (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_685 (Activation)     (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_685[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNorm)       (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_686 (Activation)     (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_686[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNorm)       (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_306 (Add)                   (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_out[0][0]
# __________________________________________________________________________________________________
# res4c_out (Activation)          (None, None, None, 1 0           add_306[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      res4c_out[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNorm)       (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_687 (Activation)     (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_687[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNorm)       (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_688 (Activation)     (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_688[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNorm)       (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_307 (Add)                   (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_out[0][0]
# __________________________________________________________________________________________________
# res4d_out (Activation)          (None, None, None, 1 0           add_307[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      res4d_out[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNorm)       (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_689 (Activation)     (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_689[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNorm)       (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_690 (Activation)     (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_690[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNorm)       (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_308 (Add)                   (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_out[0][0]
# __________________________________________________________________________________________________
# res4e_out (Activation)          (None, None, None, 1 0           add_308[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      res4e_out[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNorm)       (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_691 (Activation)     (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_691[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNorm)       (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_692 (Activation)     (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_692[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNorm)       (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_309 (Add)                   (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_out[0][0]
# __________________________________________________________________________________________________
# res4f_out (Activation)          (None, None, None, 1 0           add_309[0][0]
# __________________________________________________________________________________________________
# res4g_branch2a (Conv2D)         (None, None, None, 2 262400      res4f_out[0][0]
# __________________________________________________________________________________________________
# bn4g_branch2a (BatchNorm)       (None, None, None, 2 1024        res4g_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_693 (Activation)     (None, None, None, 2 0           bn4g_branch2a[0][0]
# __________________________________________________________________________________________________
# res4g_branch2b (Conv2D)         (None, None, None, 2 590080      activation_693[0][0]
# __________________________________________________________________________________________________
# bn4g_branch2b (BatchNorm)       (None, None, None, 2 1024        res4g_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_694 (Activation)     (None, None, None, 2 0           bn4g_branch2b[0][0]
# __________________________________________________________________________________________________
# res4g_branch2c (Conv2D)         (None, None, None, 1 263168      activation_694[0][0]
# __________________________________________________________________________________________________
# bn4g_branch2c (BatchNorm)       (None, None, None, 1 4096        res4g_branch2c[0][0]
# __________________________________________________________________________________________________
# add_310 (Add)                   (None, None, None, 1 0           bn4g_branch2c[0][0]
#                                                                  res4f_out[0][0]
# __________________________________________________________________________________________________
# res4g_out (Activation)          (None, None, None, 1 0           add_310[0][0]
# __________________________________________________________________________________________________
# res4h_branch2a (Conv2D)         (None, None, None, 2 262400      res4g_out[0][0]
# __________________________________________________________________________________________________
# bn4h_branch2a (BatchNorm)       (None, None, None, 2 1024        res4h_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_695 (Activation)     (None, None, None, 2 0           bn4h_branch2a[0][0]
# __________________________________________________________________________________________________
# res4h_branch2b (Conv2D)         (None, None, None, 2 590080      activation_695[0][0]
# __________________________________________________________________________________________________
# bn4h_branch2b (BatchNorm)       (None, None, None, 2 1024        res4h_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_696 (Activation)     (None, None, None, 2 0           bn4h_branch2b[0][0]
# __________________________________________________________________________________________________
# res4h_branch2c (Conv2D)         (None, None, None, 1 263168      activation_696[0][0]
# __________________________________________________________________________________________________
# bn4h_branch2c (BatchNorm)       (None, None, None, 1 4096        res4h_branch2c[0][0]
# __________________________________________________________________________________________________
# add_311 (Add)                   (None, None, None, 1 0           bn4h_branch2c[0][0]
#                                                                  res4g_out[0][0]
# __________________________________________________________________________________________________
# res4h_out (Activation)          (None, None, None, 1 0           add_311[0][0]
# __________________________________________________________________________________________________
# res4i_branch2a (Conv2D)         (None, None, None, 2 262400      res4h_out[0][0]
# __________________________________________________________________________________________________
# bn4i_branch2a (BatchNorm)       (None, None, None, 2 1024        res4i_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_697 (Activation)     (None, None, None, 2 0           bn4i_branch2a[0][0]
# __________________________________________________________________________________________________
# res4i_branch2b (Conv2D)         (None, None, None, 2 590080      activation_697[0][0]
# __________________________________________________________________________________________________
# bn4i_branch2b (BatchNorm)       (None, None, None, 2 1024        res4i_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_698 (Activation)     (None, None, None, 2 0           bn4i_branch2b[0][0]
# __________________________________________________________________________________________________
# res4i_branch2c (Conv2D)         (None, None, None, 1 263168      activation_698[0][0]
# __________________________________________________________________________________________________
# bn4i_branch2c (BatchNorm)       (None, None, None, 1 4096        res4i_branch2c[0][0]
# __________________________________________________________________________________________________
# add_312 (Add)                   (None, None, None, 1 0           bn4i_branch2c[0][0]
#                                                                  res4h_out[0][0]
# __________________________________________________________________________________________________
# res4i_out (Activation)          (None, None, None, 1 0           add_312[0][0]
# __________________________________________________________________________________________________
# res4j_branch2a (Conv2D)         (None, None, None, 2 262400      res4i_out[0][0]
# __________________________________________________________________________________________________
# bn4j_branch2a (BatchNorm)       (None, None, None, 2 1024        res4j_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_699 (Activation)     (None, None, None, 2 0           bn4j_branch2a[0][0]
# __________________________________________________________________________________________________
# res4j_branch2b (Conv2D)         (None, None, None, 2 590080      activation_699[0][0]
# __________________________________________________________________________________________________
# bn4j_branch2b (BatchNorm)       (None, None, None, 2 1024        res4j_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_700 (Activation)     (None, None, None, 2 0           bn4j_branch2b[0][0]
# __________________________________________________________________________________________________
# res4j_branch2c (Conv2D)         (None, None, None, 1 263168      activation_700[0][0]
# __________________________________________________________________________________________________
# bn4j_branch2c (BatchNorm)       (None, None, None, 1 4096        res4j_branch2c[0][0]
# __________________________________________________________________________________________________
# add_313 (Add)                   (None, None, None, 1 0           bn4j_branch2c[0][0]
#                                                                  res4i_out[0][0]
# __________________________________________________________________________________________________
# res4j_out (Activation)          (None, None, None, 1 0           add_313[0][0]
# __________________________________________________________________________________________________
# res4k_branch2a (Conv2D)         (None, None, None, 2 262400      res4j_out[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2a (BatchNorm)       (None, None, None, 2 1024        res4k_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_701 (Activation)     (None, None, None, 2 0           bn4k_branch2a[0][0]
# __________________________________________________________________________________________________
# res4k_branch2b (Conv2D)         (None, None, None, 2 590080      activation_701[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2b (BatchNorm)       (None, None, None, 2 1024        res4k_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_702 (Activation)     (None, None, None, 2 0           bn4k_branch2b[0][0]
# __________________________________________________________________________________________________
# res4k_branch2c (Conv2D)         (None, None, None, 1 263168      activation_702[0][0]
# __________________________________________________________________________________________________
# bn4k_branch2c (BatchNorm)       (None, None, None, 1 4096        res4k_branch2c[0][0]
# __________________________________________________________________________________________________
# add_314 (Add)                   (None, None, None, 1 0           bn4k_branch2c[0][0]
#                                                                  res4j_out[0][0]
# __________________________________________________________________________________________________
# res4k_out (Activation)          (None, None, None, 1 0           add_314[0][0]
# __________________________________________________________________________________________________
# res4l_branch2a (Conv2D)         (None, None, None, 2 262400      res4k_out[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2a (BatchNorm)       (None, None, None, 2 1024        res4l_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_703 (Activation)     (None, None, None, 2 0           bn4l_branch2a[0][0]
# __________________________________________________________________________________________________
# res4l_branch2b (Conv2D)         (None, None, None, 2 590080      activation_703[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2b (BatchNorm)       (None, None, None, 2 1024        res4l_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_704 (Activation)     (None, None, None, 2 0           bn4l_branch2b[0][0]
# __________________________________________________________________________________________________
# res4l_branch2c (Conv2D)         (None, None, None, 1 263168      activation_704[0][0]
# __________________________________________________________________________________________________
# bn4l_branch2c (BatchNorm)       (None, None, None, 1 4096        res4l_branch2c[0][0]
# __________________________________________________________________________________________________
# add_315 (Add)                   (None, None, None, 1 0           bn4l_branch2c[0][0]
#                                                                  res4k_out[0][0]
# __________________________________________________________________________________________________
# res4l_out (Activation)          (None, None, None, 1 0           add_315[0][0]
# __________________________________________________________________________________________________
# res4m_branch2a (Conv2D)         (None, None, None, 2 262400      res4l_out[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2a (BatchNorm)       (None, None, None, 2 1024        res4m_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_705 (Activation)     (None, None, None, 2 0           bn4m_branch2a[0][0]
# __________________________________________________________________________________________________
# res4m_branch2b (Conv2D)         (None, None, None, 2 590080      activation_705[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2b (BatchNorm)       (None, None, None, 2 1024        res4m_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_706 (Activation)     (None, None, None, 2 0           bn4m_branch2b[0][0]
# __________________________________________________________________________________________________
# res4m_branch2c (Conv2D)         (None, None, None, 1 263168      activation_706[0][0]
# __________________________________________________________________________________________________
# bn4m_branch2c (BatchNorm)       (None, None, None, 1 4096        res4m_branch2c[0][0]
# __________________________________________________________________________________________________
# add_316 (Add)                   (None, None, None, 1 0           bn4m_branch2c[0][0]
#                                                                  res4l_out[0][0]
# __________________________________________________________________________________________________
# res4m_out (Activation)          (None, None, None, 1 0           add_316[0][0]
# __________________________________________________________________________________________________
# res4n_branch2a (Conv2D)         (None, None, None, 2 262400      res4m_out[0][0]
# __________________________________________________________________________________________________
# bn4n_branch2a (BatchNorm)       (None, None, None, 2 1024        res4n_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_707 (Activation)     (None, None, None, 2 0           bn4n_branch2a[0][0]
# __________________________________________________________________________________________________
# res4n_branch2b (Conv2D)         (None, None, None, 2 590080      activation_707[0][0]
# __________________________________________________________________________________________________
# bn4n_branch2b (BatchNorm)       (None, None, None, 2 1024        res4n_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_708 (Activation)     (None, None, None, 2 0           bn4n_branch2b[0][0]
# __________________________________________________________________________________________________
# res4n_branch2c (Conv2D)         (None, None, None, 1 263168      activation_708[0][0]
# __________________________________________________________________________________________________
# bn4n_branch2c (BatchNorm)       (None, None, None, 1 4096        res4n_branch2c[0][0]
# __________________________________________________________________________________________________
# add_317 (Add)                   (None, None, None, 1 0           bn4n_branch2c[0][0]
#                                                                  res4m_out[0][0]
# __________________________________________________________________________________________________
# res4n_out (Activation)          (None, None, None, 1 0           add_317[0][0]
# __________________________________________________________________________________________________
# res4o_branch2a (Conv2D)         (None, None, None, 2 262400      res4n_out[0][0]
# __________________________________________________________________________________________________
# bn4o_branch2a (BatchNorm)       (None, None, None, 2 1024        res4o_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_709 (Activation)     (None, None, None, 2 0           bn4o_branch2a[0][0]
# __________________________________________________________________________________________________
# res4o_branch2b (Conv2D)         (None, None, None, 2 590080      activation_709[0][0]
# __________________________________________________________________________________________________
# bn4o_branch2b (BatchNorm)       (None, None, None, 2 1024        res4o_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_710 (Activation)     (None, None, None, 2 0           bn4o_branch2b[0][0]
# __________________________________________________________________________________________________
# res4o_branch2c (Conv2D)         (None, None, None, 1 263168      activation_710[0][0]
# __________________________________________________________________________________________________
# bn4o_branch2c (BatchNorm)       (None, None, None, 1 4096        res4o_branch2c[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNorm)       (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_328 (Add)                   (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_out[0][0]
# __________________________________________________________________________________________________
# res5b_out (Activation)          (None, None, None, 2 0           add_328[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     res5b_out[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNorm)       (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_731 (Activation)     (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_731[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNorm)       (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_732 (Activation)     (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_732[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNorm)       (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_329 (Add)                   (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_out[0][0]
# __________________________________________________________________________________________________
# res5c_out (Activation)          (None, None, None, 2 0           add_329[0][0]
# __________________________________________________________________________________________________
# fpn_c5p5 (Conv2D)               (None, None, None, 2 524544      res5c_out[0][0]
# __________________________________________________________________________________________________
# fpn_p5upsampled (UpSampling2D)  (None, None, None, 2 0           fpn_c5p5[0][0]
# __________________________________________________________________________________________________
# fpn_c4p4 (Conv2D)               (None, None, None, 2 262400      res4w_out[0][0]
# __________________________________________________________________________________________________
# fpn_p4add (Add)                 (None, None, None, 2 0           fpn_p5upsampled[0][0]
#                                                                  fpn_c4p4[0][0]
# __________________________________________________________________________________________________
# fpn_p4upsampled (UpSampling2D)  (None, None, None, 2 0           fpn_p4add[0][0]
# __________________________________________________________________________________________________
# fpn_c3p3 (Conv2D)               (None, None, None, 2 131328      res3d_out[0][0]
# __________________________________________________________________________________________________
# fpn_p3add (Add)                 (None, None, None, 2 0           fpn_p4upsampled[0][0]
#                                                                  fpn_c3p3[0][0]
# __________________________________________________________________________________________________
# fpn_p3upsampled (UpSampling2D)  (None, None, None, 2 0           fpn_p3add[0][0]
# __________________________________________________________________________________________________
# fpn_c2p2 (Conv2D)               (None, None, None, 2 65792       res2c_out[0][0]
# __________________________________________________________________________________________________
# fpn_p2add (Add)                 (None, None, None, 2 0           fpn_p3upsampled[0][0]
#                                                                  fpn_c2p2[0][0]
# __________________________________________________________________________________________________
# fpn_p5 (Conv2D)                 (None, None, None, 2 590080      fpn_c5p5[0][0]
# __________________________________________________________________________________________________
# fpn_p2 (Conv2D)                 (None, None, None, 2 590080      fpn_p2add[0][0]
# __________________________________________________________________________________________________
# fpn_p3 (Conv2D)                 (None, None, None, 2 590080      fpn_p3add[0][0]
# __________________________________________________________________________________________________
# fpn_p4 (Conv2D)                 (None, None, None, 2 590080      fpn_p4add[0][0]
# __________________________________________________________________________________________________
# fpn_p6 (MaxPooling2D)           (None, None, None, 2 0           fpn_p5[0][0]
# __________________________________________________________________________________________________
# rpn_model (Functional)          [(None, None, 2), (N 1189394     fpn_p2[0][0]
#                                                                  fpn_p3[0][0]
#                                                                  fpn_p4[0][0]
#                                                                  fpn_p5[0][0]
#                                                                  fpn_p6[0][0]
# __________________________________________________________________________________________________
# rpn_class (Concatenate)         (None, None, 2)      0           rpn_model[0][1]
#                                                                  rpn_model[1][1]
#                                                                  rpn_model[2][1]
#                                                                  rpn_model[3][1]
#                                                                  rpn_model[4][1]
# __________________________________________________________________________________________________
# rpn_bbox (Concatenate)          (None, None, 4)      0           rpn_model[0][2]
#                                                                  rpn_model[1][2]
#                                                                  rpn_model[2][2]
#                                                                  rpn_model[3][2]
#                                                                  rpn_model[4][2]
# __________________________________________________________________________________________________
# input_anchors (InputLayer)      [(None, None, 4)]    0
# __________________________________________________________________________________________________
# ROI (ProposalLayer)             (1, 1000, 4)         0           rpn_class[0][0]
#                                                                  rpn_bbox[0][0]
#                                                                  input_anchors[0][0]
# __________________________________________________________________________________________________
# input_image_meta (InputLayer)   [(None, 15)]         0
# __________________________________________________________________________________________________
# roi_align_classifier (PyramidRO (1, 1000, 7, 7, 256) 0           ROI[0][0]
#                                                                  input_image_meta[0][0]
#                                                                  fpn_p2[0][0]
#                                                                  fpn_p3[0][0]
#                                                                  fpn_p4[0][0]
#                                                                  fpn_p5[0][0]
# __________________________________________________________________________________________________
# mrcnn_class_conv1 (TimeDistribu (1, 1000, 1, 1, 1024 12846080    roi_align_classifier[0][0]
# __________________________________________________________________________________________________
# mrcnn_class_bn1 (TimeDistribute (1, 1000, 1, 1, 1024 4096        mrcnn_class_conv1[0][0]
# __________________________________________________________________________________________________
# activation_733 (Activation)     (1, 1000, 1, 1, 1024 0           mrcnn_class_bn1[0][0]
# __________________________________________________________________________________________________
# mrcnn_class_conv2 (TimeDistribu (1, 1000, 1, 1, 1024 1049600     activation_733[0][0]
# __________________________________________________________________________________________________
# mrcnn_class_bn2 (TimeDistribute (1, 1000, 1, 1, 1024 4096        mrcnn_class_conv2[0][0]
# __________________________________________________________________________________________________
# activation_734 (Activation)     (1, 1000, 1, 1, 1024 0           mrcnn_class_bn2[0][0]
# __________________________________________________________________________________________________
# pool_squeeze (Lambda)           (1, 1000, 1024)      0           activation_734[0][0]
# __________________________________________________________________________________________________
# mrcnn_class_logits (TimeDistrib (1, 1000, 3)         3075        pool_squeeze[0][0]
# __________________________________________________________________________________________________
# mrcnn_bbox_fc (TimeDistributed) (1, 1000, 12)        12300       pool_squeeze[0][0]
# __________________________________________________________________________________________________
# mrcnn_class (TimeDistributed)   (1, 1000, 3)         0           mrcnn_class_logits[0][0]
# __________________________________________________________________________________________________
# mrcnn_bbox (Reshape)            (1, 1000, 3, 4)      0           mrcnn_bbox_fc[0][0]
# __________________________________________________________________________________________________
# mrcnn_detection (DetectionLayer (1, 100, 6)          0           ROI[0][0]
#                                                                  mrcnn_class[0][0]
#                                                                  mrcnn_bbox[0][0]
#                                                                  input_image_meta[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (1, 100, 4)          0           mrcnn_detection[0][0]
# __________________________________________________________________________________________________
# roi_align_mask (PyramidROIAlign (1, 100, 14, 14, 256 0           lambda_31[0][0]
#                                                                  input_image_meta[0][0]
#                                                                  fpn_p2[0][0]
#                                                                  fpn_p3[0][0]
#                                                                  fpn_p4[0][0]
#                                                                  fpn_p5[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_conv1 (TimeDistribut (1, 100, 14, 14, 256 590080      roi_align_mask[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_bn1 (TimeDistributed (1, 100, 14, 14, 256 1024        mrcnn_mask_conv1[0][0]
# __________________________________________________________________________________________________
# activation_736 (Activation)     (1, 100, 14, 14, 256 0           mrcnn_mask_bn1[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_conv2 (TimeDistribut (1, 100, 14, 14, 256 590080      activation_736[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_bn2 (TimeDistributed (1, 100, 14, 14, 256 1024        mrcnn_mask_conv2[0][0]
# __________________________________________________________________________________________________
# activation_737 (Activation)     (1, 100, 14, 14, 256 0           mrcnn_mask_bn2[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_conv3 (TimeDistribut (1, 100, 14, 14, 256 590080      activation_737[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_bn3 (TimeDistributed (1, 100, 14, 14, 256 1024        mrcnn_mask_conv3[0][0]
# __________________________________________________________________________________________________
# activation_738 (Activation)     (1, 100, 14, 14, 256 0           mrcnn_mask_bn3[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_conv4 (TimeDistribut (1, 100, 14, 14, 256 590080      activation_738[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_bn4 (TimeDistributed (1, 100, 14, 14, 256 1024        mrcnn_mask_conv4[0][0]
# __________________________________________________________________________________________________
# activation_739 (Activation)     (1, 100, 14, 14, 256 0           mrcnn_mask_bn4[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask_deconv (TimeDistribu (1, 100, 28, 28, 256 262400      activation_739[0][0]
# __________________________________________________________________________________________________
# mrcnn_mask (TimeDistributed)    (1, 100, 28, 28, 3)  771         mrcnn_mask_deconv[0][0]
# ==================================================================================================
# Total params: 63,738,788
# Trainable params: 63,627,300
# Non-trainable params: 111,488
# __________________________________________________________________________________________________

# %%
class InferenceConfig(CustomConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    USE_MINI_MASK = False

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
model_path = os.path.join(ROOT_DIR, "model_finetune.h5")
#model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/model_finetune.h5

# %%
# !cd /content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0 ; python setup.py install
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# error: package directory 'mrcnn' does not exist

# %%
# Test on a random image
from model import log
image_id = random.choice(dataset_val.image_ids)
#image_id=(ROOT_DIR,'test5.jpg')
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (15,)                 min:    0.00000  max: 1024.00000  float64
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (1, 4)                min:  335.00000  max:  827.00000  int32
# gt_mask                  shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  uint8

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
def color_splash(image, mask):
    """Apply color splash effect.
    image: RGB image [height, width, 3]
    mask: instance segmentation mask [height, width, instance count]

    Returns result image.
    """
    # Make a grayscale copy of the image. The grayscale copy still
    # has 3 RGB channels, though.
    gray = skimage.color.gray2rgb(skimage.color.rgb2gray(image)) * 255
    # Copy color pixels from the original color image where mask is set
    if mask.shape[-1] > 0:
        # We're treating all instances as one, so collapse the mask into one layer
        mask = (np.sum(mask, -1, keepdims=True) >= 1)
        splash = np.where(mask, image, gray).astype(np.uint8)
    else:
        splash = gray.astype(np.uint8)
    return splash


def detect_and_color_splash(model, image_path=None, video_path=None):
    assert image_path or video_path

    # Image or video?
    if image_path:
        # Run model detection and generate the color splash effect
        #print("Running on {}".format(.image))
        # Read image
        image = skimage.io.imread(image_path)
        # Detect objects
        r = model.detect([image], verbose=1)[0]
        # Color splash
        splash = color_splash(image, r['masks'])
        # Save output
        file_name = "splash_{:%Y%m%dT%H%M%S}.png".format(datetime.datetime.now())
        skimage.io.imsave(file_name, splash)
    elif video_path:
        import cv2
        # Video capture
        vcapture = cv2.VideoCapture(video_path)
        width = int(vcapture.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(vcapture.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = vcapture.get(cv2.CAP_PROP_FPS)

        # Define codec and create video writer
        file_name = "splash_{:%Y%m%dT%H%M%S}.avi".format(datetime.datetime.now())
        vwriter = cv2.VideoWriter(file_name,
                                  cv2.VideoWriter_fourcc(*'MJPG'),
                                  fps, (width, height))

        count = 0
        success = True
        while success:
            print("frame: ", count)
            # Read next image
            success, image = vcapture.read()
            if success:
                # OpenCV returns images as BGR, convert to RGB
                image = image[..., ::-1]
                # Detect objects
                r = model.detect([image], verbose=0)[0]
                # Color splash
                splash = color_splash(image, r['masks'])
                # RGB -> BGR to save image to video
                splash = splash[..., ::-1]
                # Add image to video writer
                vwriter.write(splash)
                count += 1
        vwriter.release()
    print("Saved to ", file_name)

# %%
import datetime

# %%
image = skimage.io.imread(os.path.join(ROOT_DIR, 'dataset/test/test1.jpg'))

 # Run object detection

detect_and_color_splash(model, image_path='/content/CarDamage_tf2_gpu/Mask_RCNN-tensorflow-2.0/dataset/test/test1.jpg')
results = model.detect([image], verbose=1)                                
  # Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                              dataset_train.class_names, r['scores'], ax=ax,
                              title="Predictions")
#visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            #dataset_val.class_names, r['scores'], ax=get_ax())
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
# Out:
# Processing 1 images
# image                    shape: (1415, 2119, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 15)               min:    0.00000  max: 2119.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# Saved to  splash_20210818T112559.png
# Processing 1 images
# image                    shape: (1415, 2119, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 15)               min:    0.00000  max: 2119.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (1, 4)                min:  345.00000  max:  625.00000  int32
# gt_mask                  shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  uint8

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# mAP:  0.0

# %%
"""
Mask R-CNN
Train on the toy Balloon dataset and implement color splash effect.

Copyright (c) 2018 Matterport, Inc.
Licensed under the MIT License (see LICENSE for details)
Written by Waleed Abdulla
Edited for general application by Soumya Yadav (Psoumyadav@gmail.com)

------------------------------------------------------------

Usage: import the module (see Jupyter notebooks for examples), or run from
       the command line as such:

    # Train a new model starting from pre-trained COCO weights
    python3 balloon.py train --dataset=/path/to/balloon/dataset --weights=coco

    # Resume training a model that you had trained earlier
    python3 balloon.py train --dataset=/path/to/balloon/dataset --weights=last

    # Train a new model starting from ImageNet weights
    python3 balloon.py train --dataset=/path/to/balloon/dataset --weights=imagenet

    # Apply color splash to an image
    python3 balloon.py splash --weights=/path/to/weights/file.h5 --image=<URL or path to file>

    # Apply color splash to video using the last weights you trained
    python3 balloon.py splash --weights=last --video=<URL or path to file>
"""


############################################################
#  Configurations
############################################################
############################################################
#  Dataset
############################################################

############################################################
#  Training
############################################################

if __name__ == '__main__':
    import argparse

    # Parse command line arguments
    parser = argparse.ArgumentParser(
        description='Train Mask R-CNN to detect custom objects.')
    parser.add_argument("command",
                        metavar="<command>",
                        help="'train' or 'splash'")
    parser.add_argument('--dataset', required=False,
                        metavar="/path/to/custom/dataset/",
                        help='Directory of the custom dataset')
    parser.add_argument('--weights', required=True,
                        metavar="/path/to/weights.h5",
                        help="Path to weights .h5 file or 'coco'")
    parser.add_argument('--logs', required=False,
                        default=DEFAULT_LOGS_DIR,
                        metavar="/path/to/logs/",
                        help='Logs and checkpoints directory (default=logs/)')
    parser.add_argument('--image', required=False,
                        metavar="path or URL to image",
                        help='Image to apply the color splash effect on')
    parser.add_argument('--video', required=False,
                        metavar="path or URL to video",
                        help='Video to apply the color splash effect on')
    args = parser.parse_args()

    # Validate arguments
    if args.command == "train":
        assert args.dataset, "Argument --dataset is required for training"
    elif args.command == "splash":
        assert args.image or args.video,\
               "Provide --image or --video to apply color splash"

    print("Weights: ", args.weights)
    print("Dataset: ", args.dataset)
    print("Logs: ", args.logs)

    # Configurations
    if args.command == "train":
        config = CustomConfig()
    else:
        class InferenceConfig(CustomConfig):
            # Set batch size to 1 since we'll be running inference on
            # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
            GPU_COUNT = 1
            IMAGES_PER_GPU = 1
        config = InferenceConfig()
    config.display()

    # Create model
    if args.command == "train":
        model = modellib.MaskRCNN(mode="training", config=config,
                                  model_dir=args.logs)
    else:
        model = modellib.MaskRCNN(mode="inference", config=config,
                                  model_dir=args.logs)

    # Select weights file to load
    if args.weights.lower() == "new":	
        print("weight path entered")	
        print(NEW_WEIGHTS_PATH)	
        weights_path = NEW_WEIGHTS_PATH
    if args.weights.lower() == "coco":
        weights_path = COCO_WEIGHTS_PATH
        # Download weights file
        if not os.path.exists(weights_path):
            utils.download_trained_weights(weights_path)
    elif args.weights.lower() == "last":
        # Find last trained weights
        weights_path = model.find_last()
    elif args.weights.lower() == "imagenet":
        # Start from ImageNet trained weights
        weights_path = model.get_imagenet_weights()
    else:
        weights_path = args.weights

    # Load weights
    print("Loading weights ", weights_path)
    if args.weights.lower() == "coco":
        # Exclude the last layers because they require a matching
        # number of classes
        model.load_weights(weights_path, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])
    else:
        model.load_weights(weights_path, by_name=True)

    # Train or evaluate
    if args.command == "train":
        train(model)
    elif args.command == "splash":
        detect_and_color_splash(model, image_path=args.image,
                                video_path=args.video)
    else:
        print("'{}' is not recognized. "
              "Use 'train' or 'splash'".format(args.command))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-04a5d2b89cad> in <module>()
#      57                         help="Path to weights .h5 file or 'coco'")
#      58     parser.add_argument('--logs', required=False,
# ---> 59                         default=DEFAULT_LOGS_DIR,
#      60                         metavar="/path/to/logs/",
#      61                         help='Logs and checkpoints directory (default=logs/)')
#
# NameError: name 'DEFAULT_LOGS_DIR' is not defined
