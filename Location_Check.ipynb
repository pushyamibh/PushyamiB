# %% [markdown]
# <a href="https://colab.research.google.com/github/PushyamiB/PushyamiB/blob/circleci-project-setup/Location_Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Car-Damage-Analysis-App-master.zip
# Out:
# Archive:  /content/drive/MyDrive/Car-Damage-Analysis-App-master.zip
#    creating: Car-Damage-Analysis-App-master/
#    creating: Car-Damage-Analysis-App-master/.ipynb_checkpoints/
#   inflating: Car-Damage-Analysis-App-master/.ipynb_checkpoints/Damaged_Check-checkpoint.ipynb
#   inflating: Car-Damage-Analysis-App-master/.ipynb_checkpoints/Location_Check-checkpoint.ipynb
#   inflating: Car-Damage-Analysis-App-master/.ipynb_checkpoints/Severity_Check-checkpoint.ipynb
#    creating: Car-Damage-Analysis-App-master/Actual photos/
#   inflating: Car-Damage-Analysis-App-master/Actual photos/1.jpeg
#   inflating: Car-Damage-Analysis-App-master/Actual photos/2.jpeg
#   inflating: Car-Damage-Analysis-App-master/Actual photos/3.jpeg
#   inflating: Car-Damage-Analysis-App-master/Actual photos/4.jpeg
#   inflating: Car-Damage-Analysis-App-master/Actual photos/5.jpeg
#   inflating: Car-Damage-Analysis-App-master/Damaged_Check.ipynb
#   inflating: Car-Damage-Analysis-App-master/Dockerfile
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0,3"

# %%
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Dense, Activation, Dropout, Flatten
from keras import optimizers
from keras.models import Sequential,load_model
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
import numpy as np 
from keras.callbacks import ModelCheckpoint, History
import os
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import seaborn as sns 
from keras import applications
from keras.models import Sequential, Model 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %%
img_width = 256
img_height = 256
train_data_dir = '/content/drive/MyDrive/data2a/training'
valid_data_dir = '/content/drive/MyDrive/data2a/validation'
fine_tuned_model_path = 'ft_model.h5'
train_samples = [len(os.listdir(train_data_dir+'/'+i)) for i in sorted(os.listdir(train_data_dir))]
nb_train_samples = sum(train_samples)
print(nb_train_samples)
validation_samples = [len(os.listdir(valid_data_dir+'/'+i)) for i in sorted(os.listdir(valid_data_dir))]
nb_validation_samples = sum(validation_samples)
print(nb_validation_samples)
epochs=50
batch_size = 8
# Out:
# 985
# 179

# %%
import tensorflow as tf

# %%
model = tf.keras.applications.DenseNet201(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
# Out:
# ...
# 74850304/74836368 [==============================] - 1s 0us/step

# %%
model.layers[703]

# %%
for layer in model.layers[:703]:
    layer.trainable = False

# %%
import random

# %%
#import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
train_damaged_list = os.listdir('/content/drive/MyDrive/data2a/training/00-front')
sample_file = random.choice(train_damaged_list)


#Getting a random rotation between -20 and 20
rotation = random.randint(-40,40)

augmentation = ImageDataGenerator(rotation_range=rotation,horizontal_flip=True)

sample_img = image.load_img('/content/drive/MyDrive/data2a/training/00-front'+'/'+sample_file)
sample_img_array = image.img_to_array(sample_img)
sample_img_array = sample_img_array.reshape((1,) + sample_img_array.shape)

samples = []
for arr,val in zip(augmentation.flow(sample_img_array, batch_size=1, save_format='jpg'),range(1)):
    img_save = image.array_to_img(arr[0], scale=False)
    samples.append(img_save)

plt.imshow(samples[0])

# %%
sample_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7FA11F27FA10>

# %%
lists= [['front','rear','side']]
data =[['data_2a']]
paths = []
def create_folders(name,class_lists,data):
    os.mkdir(name)
    for i in range(3):
        os.mkdir(name+'/'+ data)
        for j in ['train','test']:
            temp_paths = []
            os.mkdir(name+'/'+data[i]+'/'+j)
            for k in class_lists[i]:
                os.mkdir(name+'/'+data[i]+'/'+j+'/'+k)
                temp_paths.append(name+'/'+data[i]+'/'+j+'/'+k)
            paths.append(temp_paths)
create_folders('abc',lists,data)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-102-d34cf00728f5> in <module>()
#      13                 temp_paths.append(name+'/'+data[i]+'/'+j+'/'+k)
#      14             paths.append(temp_paths)
# ---> 15 create_folders('abc',lists,data)
#
# <ipython-input-102-d34cf00728f5> in create_folders(name, class_lists, data)
#       3 paths = []
#       4 def create_folders(name,class_lists,data):
# ----> 5     os.mkdir(name)
#       6     for i in range(3):
#       7         os.mkdir(name+'/'+ data)
#
# FileExistsError: [Errno 17] File exists: 'abc'

# %%
count= len(sample_img_array)
print(count)
# Out:
# 1

# %%
x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu")(x)
predictions = Dense(3, activation="softmax")(x)

model_final = Model(inputs = model.input, outputs = predictions)

model_final.compile(loss = "categorical_crossentropy", optimizer = tf.keras.optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

train_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=20)

test_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=40)

train_generator = train_datagen.flow_from_directory(
train_data_dir,
target_size = (img_height, img_width),
batch_size = batch_size, 
class_mode = "categorical")

validation_generator = test_datagen.flow_from_directory(
valid_data_dir,
target_size = (img_height, img_width),
class_mode = "categorical")

checkpoint = ModelCheckpoint("Location_densenet_final.h5", monitor='accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

#early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

model_final.fit_generator(
train_generator,
steps_per_epoch = 50,
epochs = epochs,
validation_data = validation_generator,
validation_steps = nb_validation_samples,
callbacks = [checkpoint]) #,early
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Found 985 images belonging to 3 classes.
# Found 179 images belonging to 3 classes.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# ...
# 50/50 [==============================] - 184s 3s/step - loss: 1.3302 - accuracy: 0.3537 - val_loss: 1.1266 - val_accuracy: 0.4022
#
# Epoch 00001: accuracy improved from -inf to 0.35369, saving model to Location_densenet_final.h5
# Epoch 2/50
# ...

# %%
def location_estimator(image_path, model):
    print ("Determining location of damage...")
    urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255 # this is a Numpy array with shape (1, 3, 256, 256)
    pred = model.predict(x)
    pred_label = np.argmax(pred, axis=1)
    print(pred_label)
    plt.imshow(img)
    plt.show()
    d = {0: 'Front', 1: 'Rear', 2: 'Side'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Location assessment complete.")

# %%
img = load_img('./Actual photos/1.jpeg', target_size=(256, 256))
display(img)

# %%
def location_actual_estimator(local_image_path, model):
    print ("Determining location of damage...")
#     urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
    img = load_img(local_image_path, target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255 # this is a Numpy array with shape (1, 3, 256, 256)
    pred = model.predict(x)
    pred_label = np.argmax(pred, axis=1)
    print(pred_label)
    plt.imshow(img)
    plt.show()
    d = {0: 'Front', 1: 'Rear', 2: 'Side'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Location assessment complete.")

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://c8.alamy.com/comp/EKAP5C/car-accident-damage-on-rear-end-usa-EKAP5C.jpg',model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://www.sturtevantauto.com/Content/files/CarBodyDamage.jpg', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://1.bp.blogspot.com/-ToQS-qIxYbo/UDNuV5OcVQI/AAAAAAAABdo/tjeQywWiOo0/s200/Key+scratch.jpg', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.libertymutual.com/insurance-content/copy/claims/types-of-car-damage/severe-car-damage.jpg?v=2015030112332273', model_final)
# Out:
# Determining location of damage...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-5b66fc38ce54> in <module>()
# ----> 1 location_estimator('https://www.libertymutual.com/insurance-content/copy/claims/types-of-car-damage/severe-car-damage.jpg?v=2015030112332273', model_final)
#
# <ipython-input-12-1ae3d493f3a9> in location_estimator(image_path, model)
#       1 def location_estimator(image_path, model):
#       2     print ("Determining location of damage...")
# ----> 3     urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
#       4     img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image
#       5     x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
# ...

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.side.cr/wp-content/uploads/2018/09/Connecticut-Sell-Damaged-Car.jpg', model_final)

# %%
location_estimator('data:image/jpeg;base64,...', model_final)

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9Zi5chHQrhlAxtYupxm5wH2SvYDj2T47XJ3ckLI735NjMi2xm9Q', model_final)

# %%
location_estimator('https://www.autoauctionmall.com/learning-center/contents/uploads/2015/10/damaged-car.jpg', model_final)

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRBUPvifCXSM14dO8WvFcoAQJOVQiRC8ul3YxfvMEb2lFsC0D2', model_final)

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThpYaPbP4xKXPLaTAP-p3BnkgyElfOKbV5o6VNaqt40ZjvevyO', model_final)
